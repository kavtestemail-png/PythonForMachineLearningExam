# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# https://snap.stanford.edu/data/com-Youtube.html --datasets were downloaded from  this link and "" and "" files were downloaded for the analysis

# %%
dfCmnts = pd.read_csv(r"com-youtube.top5000.cmty.txt") # Loaded the top 5000 communities file
dfUngraph = pd.read_csv(r"com-youtube.ungraph.txt") # Loaded the top 5000 communities file
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 dfCmnts = pd.read_csv(r"com-youtube.top5000.cmty.txt", sep="\t") # Loaded the top 5000 communities file
#       2 dfUngraph = pd.read_csv(r"com-youtube.ungraph.txt", sep="\t") # Loaded the top 5000 communities file
#
# ...

# %%
dfCmnts.head()
# Out:
#   72\t165\t517\t875\t1024\t1742\t2059\t2252\t2429\t3622\t5036\t5080\t5088\t5703\t5873\t6723\t6752\t8459\t8752\t8885\t9553\t10243\t10763\t13040\t13841\t15059\t15231\t15310\t16100\t19170\t19573\t20572\t26797\t27414\t28080\t28084\t28755\t40404\t43824\t48404\t48423\t48431\t61005\t83295\t103527\t108236\t139888\t156355\t156534\t175210\t180201\t181647\t181664\t181665\t183004\t203349\t224411\t279007\t282577\t287218\t319813\t458127\t526519\t645203
# 0  1\t3\t5\t539\t551\t554\t571\t626\t642\t673\t67...
# 1                                     519665\t608725
# 2                                     157240\t459129
# 3                                         590\t29649
# 4                                      84114\t382726

# %%
dfUngraph.head()
# Out:
#   # Undirected graph: ../../data/output/youtube.ungraph.txt
# 0                                          # Youtube
# 1                    # Nodes: 1134890 Edges: 2987624
# 2                             # FromNodeId\tToNodeId
# 3                                               1\t2
# 4                                               1\t3

# %% [markdown]
# Problem Statement
# With the rapid growth of social media platforms such as YouTube, understanding community engagement and content performance is essential for creators and marketers.This study aims to analyse two datasets:
# A dataset containing YouTube communities.
# The Top 5000 YouTube Communities dataset.
# The objective is to compute statistical measures and develop an algorithm to identify patterns in community engagement.

# %%
print("Mean values")
print(dfCmnts.mean())

print("Standard deviation")
print(dfCmnts.std())

print("Minimum values")
print(dfCmnts.min())

print("Maximum values")
print(dfCmnts.max())
# Out:
# Mean values
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 print("Mean values")
# ----> 2 print(dfCmnts.mean())
#       4 print("Standard deviation")
#       5 print(dfCmnts.std())
#
# File c:\Users\iklok\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\iklok\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:14461, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
# ...

# %%
class CommunityAnalyzer:

    def __init__(self, filename):
        self.filename = filename
        self.data = None

    def load_data(self):
        self.data = pd.read_csv(self.filename, sep="\t")
        print("Dataset loaded successfully")

    def summary_statistics(self):
        return self.data.describe()

    def get_top_communities(self, column, n=10):
        return self.data.sort_values(by=column, ascending=False).head(n)

    def save_summary(self, output_file):
        self.data.describe().to_csv(output_file)

# %%
class CommunityAnalyzer:

    def __init__(self, filename):
        self.filename = filename
        self.data = None

    def load_data(self):
        self.data = pd.read_csv(self.filename, sep="\t")
        print("Dataset loaded successfully")

    def summary_statistics(self):
        return self.data.describe()

    def get_top_communities(self, column, n=10):
        return self.data.sort_values(by=column, ascending=False).head(n)

    def save_summary(self, output_file):
        self.data.describe().to_csv(output_file)

# %%
for column in communities.columns:
    if communities[column].dtype != 'object':
        print(column, "Mean:", communities[column].mean())

# %%
with open("analysis_report.txt", "w") as file:
    file.write("Top 5000 Communities Summary\n")
    file.write(str(communities.describe()))
